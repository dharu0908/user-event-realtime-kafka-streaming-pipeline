-- %%
SELECT user_name, COUNT(*) AS total_events
FROM gold_user_events
where user_name!='Unknown'
GROUP BY user_name
ORDER BY total_events DESC
LIMIT 10
-- Out:
-- Databricks visualization. Run in Databricks to view.
