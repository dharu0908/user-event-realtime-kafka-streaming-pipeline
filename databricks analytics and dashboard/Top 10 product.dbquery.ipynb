-- %%
Select product_name,count(*) as total_purchased from gold_user_events
where event_type='purchase'
group by product_name
order by total_purchased desc
limit 10
-- Out:
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
